# %% [markdown]
# Deep Learning
# =============
#
# Assignment 5
# ------------
#
# The goal of this assignment is to train a Word2Vec skip-gram model over [Text8](http://mattmahoney.net/dc/textdata) data.

# %%
# These are all the modules we'll be using later. Make sure you can import them
# before proceeding further.
# %matplotlib inline
from __future__ import print_function
import collections
import math
import numpy as np
import os
import random
import tensorflow as tf
import zipfile
from matplotlib import pylab
from six.moves import range
from six.moves.urllib.request import urlretrieve
from sklearn.manifold import TSNE

# %% [markdown]
# Download the data from the source website if necessary.

# %%
url = 'http://mattmahoney.net/dc/'

def maybe_download(filename, expected_bytes):
  """Download a file if not present, and make sure it's the right size."""
  if not os.path.exists(filename):
    filename, _ = urlretrieve(url + filename, filename)
  statinfo = os.stat(filename)
  if statinfo.st_size == expected_bytes:
    print('Found and verified %s' % filename)
  else:
    print(statinfo.st_size)
    raise Exception(
      'Failed to verify ' + filename + '. Can you get to it with a browser?')
  return filename

filename = maybe_download('text8.zip', 31344016)
# Out:
# Found and verified text8.zip

# %% [markdown]
# Read the data into a string.

# %%
def read_data(filename):
  """Extract the first file enclosed in a zip file as a list of words"""
  with zipfile.ZipFile(filename) as f:
    data = tf.compat.as_str(f.read(f.namelist()[0])).split()
  return data
  
words = read_data(filename)
print('Data size %d' % len(words))
# Out:
# Data size 17005207

# %% [markdown]
# Build the dictionary and replace rare words with UNK token.

# %%
vocabulary_size = 50000

def build_dataset(words):
  count = [['UNK', -1]]
  count.extend(collections.Counter(words).most_common(vocabulary_size - 1))
  dictionary = dict()
  for word, _ in count:
    dictionary[word] = len(dictionary)
  data = list()
  unk_count = 0
  for word in words:
    if word in dictionary:
      index = dictionary[word]
    else:
      index = 0  # dictionary['UNK']
      unk_count = unk_count + 1
    data.append(index)
  count[0][1] = unk_count
  reverse_dictionary = dict(zip(dictionary.values(), dictionary.keys())) 
  return data, count, dictionary, reverse_dictionary

data, count, dictionary, reverse_dictionary = build_dataset(words)
print('Most common words (+UNK)', count[:5])
print('Sample data', data[:10])
del words  # Hint to reduce memory.
# Out:
# Most common words (+UNK) [['UNK', 418391], ('the', 1061396), ('of', 593677), ('and', 416629), ('one', 411764)]
# Sample data [5239, 3084, 12, 6, 195, 2, 3137, 46, 59, 156]

# %% [markdown]
# Function to generate a training batch for the skip-gram model.

# %%
data_index = 0

def generate_batch(batch_size, num_skips, skip_window):
  global data_index
  assert batch_size % num_skips == 0
  assert num_skips <= 2 * skip_window
  batch = np.ndarray(shape=(batch_size), dtype=np.int32)
  labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
  span = 2 * skip_window + 1 # [ skip_window target skip_window ]
  buffer = collections.deque(maxlen=span)
  for _ in range(span):
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  for i in range(batch_size // num_skips):
    target = skip_window  # target label at the center of the buffer
    targets_to_avoid = [ skip_window ]
    for j in range(num_skips):
      while target in targets_to_avoid:
        target = random.randint(0, span - 1)
      targets_to_avoid.append(target)
      batch[i * num_skips + j] = buffer[skip_window]
      labels[i * num_skips + j, 0] = buffer[target]
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  return batch, labels

print('data:', [reverse_dictionary[di] for di in data[:8]])

for num_skips, skip_window in [(2, 1), (4, 2)]:
    data_index = 0
    batch, labels = generate_batch(batch_size=8, num_skips=num_skips, skip_window=skip_window)
    print('\nwith num_skips = %d and skip_window = %d:' % (num_skips, skip_window))
    print('    batch:', [reverse_dictionary[bi] for bi in batch])
    print('    labels:', [reverse_dictionary[li] for li in labels.reshape(8)])
# Out:
# data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first']
#
# with num_skips = 2 and skip_window = 1:
#     batch: ['originated', 'originated', 'as', 'as', 'a', 'a', 'term', 'term']
#     labels: ['anarchism', 'as', 'a', 'originated', 'term', 'as', 'of', 'a']
#
# with num_skips = 4 and skip_window = 2:
#     batch: ['as', 'as', 'as', 'as', 'a', 'a', 'a', 'a']
#     labels: ['originated', 'anarchism', 'term', 'a', 'term', 'originated', 'of', 'as']

# %% [markdown]
# Train a skip-gram model.

# %%
batch_size = 128
embedding_size = 128 # Dimension of the embedding vector.
skip_window = 1 # How many words to consider left and right.
num_skips = 2 # How many times to reuse an input to generate a label.
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64 # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default(), tf.device('/cpu:0'):

  # Input data.
  train_dataset = tf.placeholder(tf.int32, shape=[batch_size])
  train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
  valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
  
  # Variables.
  embeddings = tf.Variable(
    tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
  softmax_weights = tf.Variable(
    tf.truncated_normal([vocabulary_size, embedding_size],
                         stddev=1.0 / math.sqrt(embedding_size)))
  softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))
  
  # Model.
  # Look up embeddings for inputs.
  embed = tf.nn.embedding_lookup(embeddings, train_dataset)
  # Compute the softmax loss, using a sample of the negative labels each time.
  loss = tf.reduce_mean(
    tf.nn.sampled_softmax_loss(weights=softmax_weights, biases=softmax_biases, inputs=embed,
                               labels=train_labels, num_sampled=num_sampled, num_classes=vocabulary_size))

  # Optimizer.
  # Note: The optimizer will optimize the softmax_weights AND the embeddings.
  # This is because the embeddings are defined as a variable quantity and the
  # optimizer's `minimize` method will by default modify all variable quantities 
  # that contribute to the tensor it is passed.
  # See docs on `tf.train.Optimizer.minimize()` for more details.
  optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)
  
  # Compute the similarity between minibatch examples and all embeddings.
  # We use the cosine distance:
  norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
  normalized_embeddings = embeddings / norm
  valid_embeddings = tf.nn.embedding_lookup(
    normalized_embeddings, valid_dataset)
  similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))

# %%
num_steps = 100001

with tf.Session(graph=graph) as session:
  tf.global_variables_initializer().run()
  print('Initialized')
  average_loss = 0
  for step in range(num_steps):
    batch_data, batch_labels = generate_batch(
      batch_size, num_skips, skip_window)
    feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
    _, l = session.run([optimizer, loss], feed_dict=feed_dict)
    average_loss += l
    if step % 2000 == 0:
      if step > 0:
        average_loss = average_loss / 2000
      # The average loss is an estimate of the loss over the last 2000 batches.
      print('Average loss at step %d: %f' % (step, average_loss))
      average_loss = 0
    # note that this is expensive (~20% slowdown if computed every 500 steps)
    if step % 10000 == 0:
      sim = similarity.eval()
      for i in range(valid_size):
        valid_word = reverse_dictionary[valid_examples[i]]
        top_k = 8 # number of nearest neighbors
        nearest = (-sim[i, :]).argsort()[1:top_k+1]
        log = 'Nearest to %s:' % valid_word
        for k in range(top_k):
          close_word = reverse_dictionary[nearest[k]]
          log = '%s %s,' % (log, close_word)
        print(log)
  final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step 0: 7.847947
# Nearest to states: mailbox, clr, spraying, kombinate, taif, vangelis, wyman, observations,
# Nearest to with: registries, caller, buffy, northward, industrialisation, koestler, toolbar, istv,
# Nearest to many: digger, garments, summa, disjunction, mahagonny, negligible, euro, gustav,
# Nearest to is: escudo, junior, gazelle, kabaddi, perils, ramanujan, herrera, evangelicalism,
# Nearest to but: kessler, mappings, condemnation, kanons, mackey, ahenobarbus, lucifer, vested,
# Nearest to into: impeccable, sidney, know, powerpc, bundled, pilgrimages, seele, butterfield,
# Nearest to would: eurosceptics, kgf, zorn, infrequent, mises, trumpeter, expectancies, cloudy,
# Nearest to this: mikoyan, sewn, verification, ingestion, academy, ldp, aegon, equalized,
# Nearest to been: cjd, heuvelmans, formalized, logographic, solstices, clerical, nurturing, protests,
# Nearest to be: valuables, semites, brugge, virgins, collusion, organometallic, ast, vim,
# Nearest to who: sportswriter, frivolous, witches, jumbled, monarchists, installs, illogical, bulwark,
# Nearest to b: jdl, apulia, europium, zebulun, marcello, hometown, io, cnd,
# Nearest to which: increment, favors, toluene, gallons, bison, cyanobacteria, zwingli, cleve,
# Nearest to not: raider, serving, urdu, excluded, jedi, conde, incantation, internazionale,
# Nearest to were: reacts, quantified, differentiates, haifa, edessa, bulge, desired, inter,
# Nearest to new: sincerity, ea, industrialization, raucous, forays, imagines, kmaq, bolton,
# Average loss at step 2000: 4.378357
# Average loss at step 4000: 3.866699
# Average loss at step 6000: 3.786490
# Average loss at step 8000: 3.689084
# Average loss at step 10000: 3.617287
# Nearest to states: borneo, clr, mailbox, spraying, waterways, kombinate, mews, observations,
# Nearest to with: in, on, toolbar, by, disobedience, bibliographic, of, between,
# Nearest to many: some, these, maul, all, digger, legacies, ramen, garments,
# Nearest to is: was, are, has, screening, bounding, be, jointly, hips,
# Nearest to but: could, nils, vested, mappings, kanons, where, delta, although,
# Nearest to into: impeccable, linguist, powerpc, from, notables, around, bundled, ibelin,
# Nearest to would: can, will, to, does, may, must, kgf, excursion,
# Nearest to this: it, the, a, his, which, that, prescient, invaders,
# Nearest to been: logographic, was, solstices, heuvelmans, reclining, be, conflicted, re,
# Nearest to be: have, napkin, was, refer, is, come, been, are,
# Nearest to who: he, never, they, jumbled, sportswriter, goblins, pillaged, and,
# Nearest to b: hometown, zebulun, jdl, lori, hadadezer, and, europium, cluetrain,
# Nearest to which: that, it, also, this, improved, langston, charismatic, never,
# Nearest to not: to, they, generally, it, you, excluded, cerium, hijackings,
# Nearest to were: are, was, have, roosevelt, hunts, reacts, faithless, residents,
# Nearest to new: sincerity, ea, secretory, hiking, raucous, khoi, firemen, sitar,
# Average loss at step 12000: 3.605871
# Average loss at step 14000: 3.568746
# Average loss at step 16000: 3.409301
# Average loss at step 18000: 3.460640
# Average loss at step 20000: 3.544455
# Nearest to states: slang, borneo, clr, waterways, evangelion, typing, cavalcanti, lesley,
# Nearest to with: in, between, toolbar, for, cathode, and, by, into,
# Nearest to many: some, several, these, other, all, legacies, ramen, maul,
# Nearest to is: was, has, are, be, were, dru, but, if,
# Nearest to but: however, could, which, where, and, does, although, though,
# Nearest to into: from, impeccable, linguist, through, by, bowdoin, hindustani, notables,
# Nearest to would: will, can, may, could, should, must, might, does,
# Nearest to this: it, which, the, that, his, autism, a, he,
# Nearest to been: be, logographic, was, by, reclining, become, were, had,
# Nearest to be: have, been, refer, was, were, by, is, napkin,
# Nearest to who: he, never, which, they, then, unclaimed, paucity, also,
# Nearest to b: d, marriott, guangdong, cluetrain, births, rapport, maglev, jdl,
# Nearest to which: that, this, what, also, who, it, but, never,
# Nearest to not: generally, also, usually, always, actually, they, agreeing, pron,
# Nearest to were: are, had, was, have, be, discontinuous, been, is,
# Nearest to new: firemen, central, ea, khoi, hiking, hermeneutics, hasmonaean, secrets,
# Average loss at step 22000: 3.499664
# Average loss at step 24000: 3.488709
# Average loss at step 26000: 3.479198
# Average loss at step 28000: 3.484407
# Average loss at step 30000: 3.506194
# Nearest to states: slang, cavalcanti, evangelion, clr, dunsany, lesley, ways, private,
# Nearest to with: between, in, for, among, into, by, cathode, toolbar,
# Nearest to many: some, several, these, all, most, legacies, other, various,
# Nearest to is: was, has, are, were, telephus, had, be, unworthy,
# Nearest to but: however, although, though, and, when, could, truss, stevenage,
# Nearest to into: from, through, linguist, bowdoin, around, hindustani, with, impeccable,
# Nearest to would: will, can, could, may, should, must, might, does,
# Nearest to this: which, it, any, what, that, guth, not, prescient,
# Nearest to been: become, be, was, were, logographic, previously, already, had,
# Nearest to be: been, refer, have, is, were, dehydrogenase, produce, was,
# Nearest to who: he, never, they, she, which, also, there, and,
# Nearest to b: d, guangdong, rdoba, maglev, pandas, rapport, hecuba, births,
# Nearest to which: this, that, what, also, who, it, these, never,
# Nearest to not: still, actually, always, they, usually, generally, pron, this,
# Nearest to were: are, was, have, had, been, is, be, discontinuous,
# Nearest to new: central, khoi, calvinist, firemen, full, hermeneutics, ponies, field,
# Average loss at step 32000: 3.502395
# Average loss at step 34000: 3.493907
# Average loss at step 36000: 3.453395
# Average loss at step 38000: 3.299072
# Average loss at step 40000: 3.425171
# Nearest to states: slang, evangelion, cavalcanti, thierry, clr, ways, waterways, dunsany,
# Nearest to with: between, by, when, cpi, dru, besides, using, like,
# Nearest to many: some, several, these, most, all, those, maul, various,
# Nearest to is: was, has, are, if, be, became, conjectured, jointly,
# Nearest to but: however, and, though, although, while, which, are, exist,
# Nearest to into: through, from, linguist, hindustani, injurious, buckingham, hurl, up,
# Nearest to would: will, can, could, may, must, should, might, cannot,
# Nearest to this: which, it, any, that, the, another, guth, visitation,
# Nearest to been: become, be, was, previously, logographic, already, were, bae,
# Nearest to be: been, refer, have, was, are, is, being, by,
# Nearest to who: which, he, she, never, often, also, they, still,
# Nearest to b: d, UNK, hawthorn, r, j, c, vida, e,
# Nearest to which: that, this, also, often, who, what, these, it,
# Nearest to not: actually, always, usually, generally, still, pron, often, they,
# Nearest to were: are, have, was, had, while, be, been, although,
# Nearest to new: central, secrets, khoi, aau, light, firemen, hermeneutics, calvinist,
# Average loss at step 42000: 3.433435
# Average loss at step 44000: 3.459047
# Average loss at step 46000: 3.447881
# Average loss at step 48000: 3.353556
# Average loss at step 50000: 3.383194
# Nearest to states: slang, evangelion, clr, kingdom, lesley, thierry, cavalcanti, dunsany,
# Nearest to with: between, by, in, against, toolbar, hitchens, cesium, including,
# Nearest to many: some, several, these, various, those, most, maul, both,
# Nearest to is: was, has, are, contains, putney, does, puncture, although,
# Nearest to but: however, and, when, though, although, than, which, while,
# Nearest to into: through, from, linguist, hindustani, encrusted, bowdoin, hurl, around,
# Nearest to would: will, could, can, may, should, must, might, did,
# Nearest to this: which, it, the, that, apparitions, there, cahiers, eastman,
# Nearest to been: become, be, was, previously, logographic, already, confusingly, were,
# Nearest to be: have, been, refer, being, was, were, lead, baronies,
# Nearest to who: he, she, which, never, i, there, often, they,
# Nearest to b: d, r, ulf, f, c, transcriptase, bazille, vida,
# Nearest to which: that, this, what, also, who, but, often, these,
# Nearest to not: actually, always, usually, generally, still, often, pron, humiliating,
# Nearest to were: are, was, have, had, although, silicon, be, investigated,
# Nearest to new: central, khoi, full, secrets, local, standard, aau, light,
# Average loss at step 52000: 3.437460
# Average loss at step 54000: 3.427920
# Average loss at step 56000: 3.436510
# Average loss at step 58000: 3.398368
# Average loss at step 60000: 3.390053
# Nearest to states: nations, slang, kingdom, dtmf, evangelion, thierry, state, sighted,
# Nearest to with: between, cesium, including, toolbar, among, silenced, cathode, in,
# Nearest to many: some, several, these, various, most, both, all, such,
# Nearest to is: was, are, has, does, includes, be, putney, cds,
# Nearest to but: however, although, and, though, than, when, exist, since,
# Nearest to into: through, from, linguist, bowdoin, brandy, around, over, golden,
# Nearest to would: could, will, may, can, must, should, might, did,
# Nearest to this: it, which, that, there, some, the, herbrand, any,
# Nearest to been: become, be, was, previously, logographic, already, were, bae,
# Nearest to be: been, refer, was, have, being, are, become, were,
# Nearest to who: she, never, he, which, still, often, northridge, they,
# Nearest to b: d, r, c, transcriptase, f, n, emilia, inker,
# Nearest to which: that, this, what, these, also, who, it, aggressor,
# Nearest to not: usually, still, always, actually, pron, now, generally, they,
# Nearest to were: are, have, was, had, including, although, those, while,
# Nearest to new: full, secrets, aau, reins, modern, ea, nutritional, central,
# Average loss at step 62000: 3.235336
# Average loss at step 64000: 3.256649
# Average loss at step 66000: 3.404585
# Average loss at step 68000: 3.397612
# Average loss at step 70000: 3.361069
# Nearest to states: nations, state, kingdom, dtmf, slang, evangelion, grappelli, kant,
# Nearest to with: between, toolbar, kabaddi, errico, wollheim, by, bibliographic, silenced,
# Nearest to many: some, several, these, various, most, all, legacies, both,
# Nearest to is: was, has, are, be, contains, involves, although, jointly,
# Nearest to but: however, though, although, that, which, than, while, and,
# Nearest to into: through, from, linguist, bowdoin, hologram, around, within, presenters,
# Nearest to would: will, could, may, can, should, might, must, cannot,
# Nearest to this: which, it, that, another, there, the, any, visitation,
# Nearest to been: become, be, was, previously, already, logographic, were, bae,
# Nearest to be: been, is, being, are, were, have, become, refer,
# Nearest to who: never, she, he, still, they, which, pippin, often,
# Nearest to b: d, r, f, j, mortis, n, rdoba, transcriptase,
# Nearest to which: that, this, also, what, but, these, often, usually,
# Nearest to not: actually, always, still, usually, now, generally, also, never,
# Nearest to were: are, have, was, had, be, although, including, been,
# Nearest to new: full, secrets, tanakh, frightful, firemen, nutritional, aau, reins,
# Average loss at step 72000: 3.375309
# Average loss at step 74000: 3.348437
# Average loss at step 76000: 3.322459
# Average loss at step 78000: 3.353931
# Average loss at step 80000: 3.376218
# Nearest to states: nations, kingdom, state, slang, countries, dunsany, russia, lesley,
# Nearest to with: between, toolbar, when, including, bibliographic, explains, wollheim, against,
# Nearest to many: some, several, various, these, most, all, those, numerous,
# Nearest to is: was, has, are, includes, contains, be, becomes, although,
# Nearest to but: however, although, though, and, than, while, dictates, or,
# Nearest to into: through, from, around, back, equator, hologram, over, toland,
# Nearest to would: could, will, may, can, must, might, should, cannot,
# Nearest to this: it, which, the, another, middleware, there, visitation, he,
# Nearest to been: become, be, was, previously, already, were, bae, logographic,
# Nearest to be: been, being, have, refer, become, is, are, unambiguous,
# Nearest to who: he, she, never, which, they, often, still, there,
# Nearest to b: d, r, c, f, transcriptase, p, amour, mortis,
# Nearest to which: that, this, these, who, also, usually, what, it,
# Nearest to not: still, always, actually, usually, almost, generally, often, now,
# Nearest to were: are, was, had, have, although, been, including, became,
# Nearest to new: secrets, full, tanakh, particular, reins, hasmonaean, frightful, molson,
# Average loss at step 82000: 3.410455
# Average loss at step 84000: 3.411271
# Average loss at step 86000: 3.391736
# Average loss at step 88000: 3.352959
# Average loss at step 90000: 3.365738
# Nearest to states: nations, kingdom, state, dunsany, dtmf, lesley, slang, thierry,
# Nearest to with: between, by, in, toolbar, wollheim, big, including, transonic,
# Nearest to many: some, several, these, various, numerous, all, certain, most,
# Nearest to is: was, has, are, although, involves, contains, be, does,
# Nearest to but: however, and, although, though, which, while, whispers, they,
# Nearest to into: through, from, around, bowdoin, tangent, over, within, linguist,
# Nearest to would: could, will, may, can, might, must, should, did,
# Nearest to this: it, which, another, some, the, any, herbrand, scanner,
# Nearest to been: become, be, already, previously, was, were, remained, confusingly,
# Nearest to be: been, have, refer, being, become, lead, was, is,
# Nearest to who: he, she, never, which, often, also, still, originally,
# Nearest to b: d, r, f, c, mortis, inker, transcriptase, guangdong,
# Nearest to which: that, this, also, what, usually, who, but, these,
# Nearest to not: still, always, actually, scrat, now, nor, generally, almost,
# Nearest to were: are, had, was, have, while, although, is, being,
# Nearest to new: secrets, particular, carbonated, tanakh, mobilization, restless, modern, tautologies,
# Average loss at step 92000: 3.399691
# Average loss at step 94000: 3.255985
# Average loss at step 96000: 3.358431
# Average loss at step 98000: 3.244599
# Average loss at step 100000: 3.360815
# Nearest to states: nations, kingdom, state, dunsany, lesley, infidels, thierry, dtmf,
# Nearest to with: between, in, silenced, when, suv, big, through, including,
# Nearest to many: several, some, these, various, numerous, certain, those, such,
# Nearest to is: was, has, became, be, becomes, are, contains, refers,
# Nearest to but: however, although, though, and, where, while, which, nils,
# Nearest to into: through, from, within, around, in, bowdoin, tangent, acoustic,
# Nearest to would: could, will, may, can, might, should, must, cannot,
# Nearest to this: it, which, the, herbrand, there, what, another, he,
# Nearest to been: become, be, already, previously, recently, was, confusingly, had,
# Nearest to be: been, being, is, refer, have, baronies, are, become,
# Nearest to who: he, never, she, which, often, still, also, actually,
# Nearest to b: d, french, antibacterial, cutter, guangdong, willem, pandas, tos,
# Nearest to which: that, this, what, who, usually, actually, but, also,
# Nearest to not: always, never, actually, also, pron, scrat, almost, nor,
# Nearest to were: are, have, was, although, these, had, those, include,
# Nearest to new: secrets, modern, particular, different, frightful, fictional, nutritional, ignoring,

# %%
num_points = 400

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000, method='exact')
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])

# %%
def plot(embeddings, labels):
  assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
  pylab.figure(figsize=(15,15))  # in inches
  for i, label in enumerate(labels):
    x, y = embeddings[i,:]
    pylab.scatter(x, y)
    pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points',
                   ha='right', va='bottom')
  pylab.show()

words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)

# %%
final_embeddings.shape
# Out:
# (50000, 128)

# %%
i = 6
print(words[i],final_embeddings[i])
# Out:
# to [-0.14153397  0.00942118  0.15782656  0.07233494 -0.00933012  0.13147645
#  -0.06772339  0.00969754  0.05834914 -0.19539163  0.05074978 -0.06893912
#   0.06458737  0.05845716  0.13651425 -0.15249385 -0.07566261 -0.02780106
#  -0.03576232 -0.2222652  -0.06115985 -0.03946666  0.06855803 -0.01694129
#  -0.07322942 -0.00590265 -0.03124614  0.00998672  0.16635169  0.04325326
#   0.02299134 -0.01869032  0.01639819 -0.18401183  0.05607244  0.0670857
#   0.07545109 -0.0821576   0.05250821 -0.03872126 -0.08140365  0.02238436
#  -0.04634681 -0.03970727  0.04214145  0.03342698  0.05134343 -0.02387396
#  -0.10615854  0.13271332 -0.10547853 -0.06112265  0.07391143 -0.09344054
#   0.04471584  0.14032328 -0.02326539  0.01881737 -0.03837147 -0.04999886
#  -0.01059017  0.00379652 -0.05804549  0.01477454  0.00882273 -0.03019606
#   0.02408185 -0.00053651  0.04044847 -0.13396654 -0.08988319 -0.11103974
#  -0.07626423 -0.08158899  0.17297785  0.01011194  0.01596304  0.01554686
#   0.10025964  0.05227212  0.0638745   0.11222045  0.13439082  0.30146563
#   0.16352157  0.04842491  0.00030334 -0.0644568   0.07582898 -0.01935367
#   0.00667606  0.05227503  0.00515981  0.0263941  -0.01114961 -0.10106386
#  -0.07422767  0.11655167 -0.05457916  0.1292475  -0.12471347  0.19355796
#   0.01444321  0.07066707  0.00145793  0.12505527  0.11913972 -0.06245063
#   0.14451437 -0.15026604 -0.01767328  0.08556017 -0.05877413 -0.01643789
#   0.04395293  0.07007243  0.10952686 -0.10773852 -0.03049922  0.11578939
#  -0.12913743  0.00949616  0.16838048  0.00649323  0.07873785  0.02646615
#  -0.05070093  0.01315286]

# %%
[reverse_dictionary[i] for i in range(1000,1100)]
# Out:
# ['fall',
#  'bbc',
#  'animals',
#  'existence',
#  'discovered',
#  'units',
#  'know',
#  'heavy',
#  'assembly',
#  'universe',
#  'file',
#  'smith',
#  'award',
#  'numerous',
#  'woman',
#  'mean',
#  'behind',
#  'liberal',
#  'except',
#  'scale',
#  'bill',
#  'operating',
#  'construction',
#  'active',
#  'institute',
#  'pressure',
#  'taking',
#  'san',
#  'experience',
#  'account',
#  'engine',
#  'brother',
#  'primarily',
#  'recorded',
#  'joseph',
#  'issue',
#  'professional',
#  'troops',
#  'notes',
#  'pope',
#  'centre',
#  'ice',
#  'orthodox',
#  'question',
#  'something',
#  'defense',
#  'grand',
#  'accepted',
#  'mathematics',
#  'event',
#  'resources',
#  'dr',
#  'egypt',
#  'derived',
#  'applied',
#  'paris',
#  'powers',
#  'running',
#  'stage',
#  'additional',
#  'shows',
#  'prince',
#  'placed',
#  'instance',
#  'lived',
#  'creation',
#  'freedom',
#  'alternative',
#  'http',
#  'hit',
#  'magazine',
#  'nobel',
#  'engineering',
#  'square',
#  'mainly',
#  'rise',
#  'hold',
#  'gold',
#  'pre',
#  'versions',
#  'report',
#  'road',
#  'operations',
#  'test',
#  'frac',
#  'older',
#  'arts',
#  'quite',
#  'applications',
#  'proposed',
#  'marriage',
#  'channel',
#  'shown',
#  'consists',
#  'governor',
#  'bible',
#  'police',
#  'ocean',
#  'articles',
#  'cost']

# %% [markdown]
# ---
#
# Problem
# -------
#
# An alternative to skip-gram is another Word2Vec model called [CBOW](http://arxiv.org/abs/1301.3781) (Continuous Bag of Words). In the CBOW model, instead of predicting a context word from a word vector, you predict a word from the sum of all the word vectors in its context. Implement and evaluate a CBOW model trained on the text8 dataset.
#
# ---
